# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/Users/nitishkumar/Downloads/Data_sets/IMDb_Dataset.csv")

# %%
data
# Out:
#                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 395                            Mother of the Bride          4.8  2024
# 396                        Beetlejuice Beetlejuice          7.1  2024
# 397                                The Idea of You          6.4  2024
# 398                                             IF          6.7  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 0              R     Action           Ridley Scott
# ...

# %%
#top 5 rows
data.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
#last 5 rows 
data.tail()
# Out:
#                        Title  IMDb Rating  Year Certificates      Genre  \
# 395      Mother of the Bride          4.8  2024        TV-PG     Comedy
# 396  Beetlejuice Beetlejuice          7.1  2024            R     Comedy
# 397          The Idea of You          6.4  2024            R     Comedy
# 398                       IF          6.7  2024           PG  Animation
# 399             The Fall Guy          7.1  2024        PG-13     Action
#
#               Director                                     Star Cast  \
# 395        Mark Waters  Brooke ShieldsMiranda CosgroveBenjamin Bratt
# 396         Tim Burton    Alfred GoughMiles MillarSeth Grahame-Smith
# 397  Michael Showalter     Anne HathawayNicholas GalitzineElla Rubin
# 398     John Krasinski     Cailey FlemingRyan ReynoldsJohn Krasinski
# 399       David Leitch   Ryan GoslingEmily BluntAaron Taylor-Johnson
#
#      MetaScore  Duration (minutes)
# 395       39.0                88.0
# 396       66.9               116.3
# ...

# %%
#No. of rows and columns 
data.shape
# Out:
# (400, 9)

# %%
# it shows only rows
data.shape[0]
# Out:
# 400

# %%
# it shows only columns
data.shape[1]
# Out:
# 9

# %%
# statistical description of numeric columns
data.describe()
# Out:
#        IMDb Rating         Year   MetaScore  Duration (minutes)
# count   400.000000   400.000000  400.000000          400.000000
# mean      7.110250  2015.150000   66.898750          116.334750
# std       0.932251    13.470194   15.312006           21.369757
# min       3.900000  1939.000000   26.000000           80.000000
# 25%       6.700000  2010.750000   57.750000          101.000000
# 50%       7.100000  2023.000000   66.900000          116.000000
# 75%       7.700000  2024.000000   77.000000          124.000000
# max       9.200000  2025.000000  100.000000          206.000000

# %%
#To find complete information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               400 non-null    object
#  1   IMDb Rating         400 non-null    float64
#  2   Year                400 non-null    int64
#  3   Certificates        400 non-null    object
#  4   Genre               400 non-null    object
#  5   Director            400 non-null    object
#  6   Star Cast           400 non-null    object
#  7   MetaScore           400 non-null    float64
#  8   Duration (minutes)  400 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 28.3+ KB

# %%
#to find null values
data.isnull().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
data.isnull().head(10)
# Out:
#    Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0  False        False  False         False  False     False      False
# 1  False        False  False         False  False     False      False
# 2  False        False  False         False  False     False      False
# 3  False        False  False         False  False     False      False
# 4  False        False  False         False  False     False      False
# 5  False        False  False         False  False     False      False
# 6  False        False  False         False  False     False      False
# 7  False        False  False         False  False     False      False
# 8  False        False  False         False  False     False      False
# 9  False        False  False         False  False     False      False
#
#    MetaScore  Duration (minutes)
# 0      False               False
# 1      False               False
# 2      False               False
# 3      False               False
# ...

# %%
#only columns
data.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Duration (minutes)'],
#       dtype='object')

# %%
# count
data['Certificates'].value_counts()
# Out:
# Certificates
# R            183
# PG-13         96
# PG            93
# G             16
# Not Rated      4
# TV-G           2
# 16+            2
# Approved       1
# TV-MA          1
# NC-17          1
# TV-PG          1
# Name: count, dtype: int64

# %%
data['Genre'].value_counts()
# Out:
# Genre
# Action       138
# Animation     95
# Comedy        38
# Adventure     35
# Crime         31
# Horror        29
# Drama         24
# Fantasy        5
# Biography      4
# Thriller       1
# Name: count, dtype: int64

# %%
data['Year'].value_counts()
# Out:
# Year
# 2024    143
# 2023     63
# 2022     18
# 2018     12
# 2001     11
# 2019     10
# 2015      9
# 2021      9
# 2017      8
# 2014      8
# 2016      8
# 2004      7
# 1994      6
# 2007      6
# 2013      6
# 1999      5
# 2008      5
# 1979      5
# 1984      5
# 1995      4
# 2010      4
# 1981      3
# 2005      3
# 2006      3
# 1993      3
# 2003      3
# 1997      3
# 2011      3
# 1985      3
# 2002      3
# 1996      2
# 1968      2
# 2009      2
# 2012      2
# 1987      1
# 1939      1
# 1971      1
# 2025      1
# 2000      1
# 1972      1
# 1990      1
# 1983      1
# 1991      1
# 1957      1
# 1976      1
# 1986      1
# 1988      1
# Name: count, dtype: int64

# %%
# only specific row
data[data.index == 1]
# Out:
#                                            Title  IMDb Rating  Year  \
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
#
#   Certificates   Genre               Director  \
# 1        PG-13  Action  Christopher McQuarrie
#
#                             Star Cast  MetaScore  Duration (minutes)
# 1  Tom CruiseHayley AtwellVing Rhames       81.0               163.0

# %%
#Isolating two or more rows using [ ] 
#Similarly, two or more rows can be returned using the .isin() method instead of a == operator.
data[data.index.isin(range(2,15))]
# Out:
#                                      Title  IMDb Rating  Year Certificates  \
# 2     Rebel Moon - Part Two: The Scargiver          5.2  2024        PG-13
# 3                     Inglourious Basterds          8.4  2009            R
# 4                              Borderlands          7.1  2024            R
# 5                            Jurassic Park          8.2  1993        PG-13
# 6                        The Fifth Element          7.6  1997        PG-13
# 7                               Inside Out          8.1  2015           PG
# 8             Descendants: The Rise of Red          7.1  2024         TV-G
# 9                                     Wish          5.6  2023           PG
# 10                        The Hunger Games          7.2  2012        PG-13
# 11  Rebel Moon - Part One: A Child of Fire          5.6  2023        PG-13
# 12   Harry Potter and the Sorcerer's Stone          7.6  2001           PG
# ...

# %%
data.loc[2:10]
# Out:
#                                    Title  IMDb Rating  Year Certificates  \
# 2   Rebel Moon - Part Two: The Scargiver          5.2  2024        PG-13
# 3                   Inglourious Basterds          8.4  2009            R
# 4                            Borderlands          7.1  2024            R
# 5                          Jurassic Park          8.2  1993        PG-13
# 6                      The Fifth Element          7.6  1997        PG-13
# 7                             Inside Out          8.1  2015           PG
# 8           Descendants: The Rise of Red          7.1  2024         TV-G
# 9                                   Wish          5.6  2023           PG
# 10                      The Hunger Games          7.2  2012        PG-13
#
#         Genre           Director                                Star Cast  \
# 2      Action        Zack Snyder      Zack SnyderKurt JohnstadShay Hatten
# 3   Adventure  Quentin Tarantino            Brad PittDiane KrugerEli Roth
# ...

# %%
# top 5 rating movies
data.nlargest(5,'IMDb Rating')
# Out:
#                                                  Title  IMDb Rating  Year  \
# 137                                      The Godfather          9.2  1972
# 106                                       12 Angry Men          9.0  1957
# 130                                    The Dark Knight          9.0  2008
# 15   The Lord of the Rings: The Fellowship of the Ring          8.9  2001
# 132                                       Pulp Fiction          8.9  1994
#
#     Certificates   Genre              Director  \
# 137            R   Crime  Francis Ford Coppola
# 106     Approved   Crime          Sidney Lumet
# 130        PG-13  Action     Christopher Nolan
# 15         PG-13  Action         Peter Jackson
# 132            R   Crime     Quentin Tarantino
#
#                                          Star Cast  MetaScore  \
# 137                 Mario PuzoFrancis Ford Coppola      100.0
# 106                                  Reginald Rose       97.0
# ...

# %%
# last 5 rating movies
data.nsmallest(5,'IMDb Rating')
# Out:
#                      Title  IMDb Rating  Year Certificates   Genre  \
# 43              Madame Web          3.9  2024        PG-13  Action
# 243             Madame Web          3.9  2024        PG-13  Action
# 345             Madame Web          3.9  2024        PG-13  Action
# 302  You Can't Run Forever          4.4  2024            R   Drama
# 150                Monster          4.6  2023        TV-MA  Horror
#
#                 Director                                 Star Cast  MetaScore  \
# 43         S.J. Clarkson    Matt SazamaBurk SharplessClaire Parker       26.0
# 243        S.J. Clarkson    Matt SazamaBurk SharplessClaire Parker       26.0
# 345        S.J. Clarkson    Matt SazamaBurk SharplessClaire Parker       26.0
# 302  Michelle Schumacher  J.K. SimmonsFernanda UrrejolaAllen Leech       66.9
# 150        Rako Prijanto    Marsha TimothyAlex AbbadAnantya Kirana       66.9
#
#      Duration (minutes)
# 43                116.0
# 243               116.0
# ...

# %%
# top 5 MetaScore
data.nlargest(5,'MetaScore')
# Out:
#              Title  IMDb Rating  Year Certificates      Genre  \
# 137  The Godfather          9.2  1972            R      Crime
# 106   12 Angry Men          9.0  1957     Approved      Crime
# 58       Toy Story          8.3  1995            G  Animation
# 75     Ratatouille          8.1  2007            G  Animation
# 86   Spirited Away          8.6  2001           PG  Animation
#
#                  Director                               Star Cast  MetaScore  \
# 137  Francis Ford Coppola          Mario PuzoFrancis Ford Coppola      100.0
# 106          Sidney Lumet                           Reginald Rose       97.0
# 58          John Lasseter  John LasseterPete DocterAndrew Stanton       96.0
# 75              Brad Bird      Brad BirdJan PinkavaJim Capobianco       96.0
# 86         Hayao Miyazaki                          Hayao Miyazaki       96.0
#
#      Duration (minutes)
# 137               175.0
# 106                96.0
# 58                 81.0
# 75                111.0
# ...

# %%
# last 5 MetaScore
data.nsmallest(5,'MetaScore')
# Out:
#                                       Title  IMDb Rating  Year Certificates  \
# 43                               Madame Web          3.9  2024        PG-13
# 243                              Madame Web          3.9  2024        PG-13
# 345                              Madame Web          3.9  2024        PG-13
# 271                     Garfield: The Movie          5.0  2004           PG
# 11   Rebel Moon - Part One: A Child of Fire          5.6  2023        PG-13
#
#          Genre       Director  \
# 43      Action  S.J. Clarkson
# 243     Action  S.J. Clarkson
# 345     Action  S.J. Clarkson
# 271  Adventure   Peter Hewitt
# 11      Action    Zack Snyder
#
#                                              Star Cast  MetaScore  \
# 43              Matt SazamaBurk SharplessClaire Parker       26.0
# 243             Matt SazamaBurk SharplessClaire Parker       26.0
# 345             Matt SazamaBurk SharplessClaire Parker       26.0
# ...

# %%
# top 5 duration movies
data.nlargest(5,'Duration (minutes)')
# Out:
#                           Title  IMDb Rating  Year Certificates      Genre  \
# 131  Killers of the Flower Moon          7.6  2023            R      Crime
# 104                      Animal          6.2  2023    Not Rated     Action
# 103              The Green Mile          8.6  1999            R      Crime
# 203           Avengers: Endgame          8.4  2019        PG-13     Action
# 127     The Wolf of Wall Street          8.2  2013            R  Biography
#
#                 Director                                      Star Cast  \
# 131      Martin Scorsese  Leonardo DiCaprioRobert De NiroLily Gladstone
# 104  Sandeep Reddy Vanga  Suresh BandaruSaurabh GuptaPranay Reddy Vanga
# 103       Frank Darabont      Tom HanksMichael Clarke DuncanDavid Morse
# 203        Anthony Russo      Christopher MarkusStephen McFeelyStan Lee
# 127      Martin Scorsese       Leonardo DiCaprioJonah HillMargot Robbie
#
#      MetaScore  Duration (minutes)
# 131       89.0               206.0
# ...

# %%
# last 5 duration movies
data.nsmallest(5,'Duration (minutes)')
# Out:
#                    Title  IMDb Rating  Year Certificates      Genre  \
# 271  Garfield: The Movie          5.0  2004           PG  Adventure
# 58             Toy Story          8.3  1995            G  Animation
# 91             Migration          6.7  2023           PG  Animation
# 289            Migration          6.7  2023           PG  Animation
# 352            Migration          6.7  2023           PG  Animation
#
#             Director                                          Star Cast  \
# 271     Peter Hewitt  Breckin MeyerJennifer Love HewittStephen Tobol...
# 58     John Lasseter             John LasseterPete DocterAndrew Stanton
# 91   Benjamin Renner                Mike WhiteBenjamin RennerKen Daurio
# 289  Benjamin Renner                Mike WhiteBenjamin RennerKen Daurio
# 352  Benjamin Renner                Mike WhiteBenjamin RennerKen Daurio
#
#      MetaScore  Duration (minutes)
# 271       27.0                80.0
# 58        96.0                81.0
# ...

# %%
# to find mean value
mean_value=data['IMDb Rating'].mean()
print(mean_value)
# Out:
# 7.11025

# %%
# to find median value
median_value=data['IMDb Rating'].median()
print(median_value)
# Out:
# 7.1

# %%
# to find mode value
mode_value=data['IMDb Rating'].mode()
print(mode_value)
# Out:
# 0    7.1
# Name: IMDb Rating, dtype: float64

# %%
# Comparison of IMDb ratings by genre
avg_rating_by_genre = data.groupby("Genre")["IMDb Rating"].mean()
print(avg_rating_by_genre)
# Out:
# Genre
# Action       7.080435
# Adventure    7.368571
# Animation    7.250526
# Biography    7.650000
# Comedy       6.892105
# Crime        7.587097
# Drama        6.954167
# Fantasy      6.900000
# Horror       6.337931
# Thriller     7.400000
# Name: IMDb Rating, dtype: float64

# %%
#Median IMDb Rating by Certificate
data.groupby("Certificates")["IMDb Rating"].median()
# Out:
# Certificates
# 16+          6.80
# Approved     9.00
# G            8.10
# NC-17        5.00
# Not Rated    6.60
# PG           7.10
# PG-13        7.05
# R            7.10
# TV-G         7.10
# TV-MA        4.60
# TV-PG        4.80
# Name: IMDb Rating, dtype: float64

# %%
# Average MetaScore by director
avg_metascore_by_director = data.groupby("Director")["MetaScore"].mean()
print(avg_metascore_by_director)
# Out:
# Director
# Aaron Horvath       46.00
# Adam Wingard        50.00
# Adil El Arbi        66.90
# Alex Garland        75.00
# Alex Proyas         71.00
#                     ...
# William Eubank      57.00
# Yorgos Lanthimos    80.25
# Zach Cregger        78.00
# Zack Snyder         33.00
# Zelda Williams      47.00
# Name: MetaScore, Length: 199, dtype: float64

# %%
#Top 5 Longest Movies
data.nlargest(5, "Duration (minutes)")[["Title", "Duration (minutes)"]]
# Out:
#                           Title  Duration (minutes)
# 131  Killers of the Flower Moon               206.0
# 104                      Animal               204.0
# 103              The Green Mile               189.0
# 203           Avengers: Endgame               181.0
# 127     The Wolf of Wall Street               180.0

# %% [markdown]
# # Data Visualization

# %%
data.head(20)
# Out:
#                                                 Title  IMDb Rating  Year  \
# 0                                           Gladiator          8.5  2000
# 1       Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2                Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                                Inglourious Basterds          8.4  2009
# 4                                         Borderlands          7.1  2024
# 5                                       Jurassic Park          8.2  1993
# 6                                   The Fifth Element          7.6  1997
# 7                                          Inside Out          8.1  2015
# 8                        Descendants: The Rise of Red          7.1  2024
# 9                                                Wish          5.6  2023
# 10                                   The Hunger Games          7.2  2012
# 11             Rebel Moon - Part One: A Child of Fire          5.6  2023
# ...

# %%
#Distribution of IMDb Ratings
plt.figure(figsize=(10, 8))
sns.histplot(data["IMDb Rating"], bins=10, kde=True)
plt.title("Distribution of IMDb Ratings")
plt.xlabel("IMDb Rating")
plt.ylabel("Frequency")
plt.show()

# %%
# Movies Released Over Time (Year)
plt.figure(figsize=(10, 6))
sns.countplot(x="Year", data=data,hue="Year", palette="coolwarm")
plt.title("Movies Released Over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
# Distribution of MetaScores
plt.figure(figsize=(10, 8))
sns.histplot(data["MetaScore"], bins=10, kde=True, color='green')
plt.title("Distribution of MetaScores")
plt.xlabel("MetaScore")
plt.ylabel("Frequency")
plt.show()

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# %%
correlation_matrix = data[['IMDb Rating', 'Year', 'MetaScore', 'Duration (minutes)']].corr()

#Heatmap of correlation between variables
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Heatmap of Correlation Between Variables")
plt.show()

# %%
#Bar Plot of Movies Per Genre
plt.figure(figsize=(10, 8))
sns.countplot(data,x="Genre",hue="Genre", palette="muted")
plt.title("Movies per Genre")
plt.xlabel("Genre")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
# Boxplot of IMDb Ratings by Certificates
plt.figure(figsize=(10, 8))
sns.boxplot(x="Certificates", y="IMDb Rating", data=data,hue="Certificates", palette="coolwarm")
plt.title("Boxplot of IMDb Ratings by Certificates")
plt.show()

# %%
# Bar Plot of Top 5 Directors by Average IMDb Rating
top_5_directors_imdb = data.groupby("Director")["IMDb Rating"].mean().nlargest(5)
plt.figure(figsize=(10, 8))
sns.barplot(x=top_5_directors_imdb.index, y=top_5_directors_imdb.values, color='red')
plt.title("Top 5 Directors by Average IMDb Rating")
plt.ylabel("Average IMDb Rating")
plt.xlabel("Director")
plt.xticks(rotation=45)
plt.show()

# %%
# Violin Plot of IMDb Rating by Genre
plt.figure(figsize=(10, 8))
sns.violinplot(x="Genre", y="IMDb Rating", data=data,hue="Genre", palette="pastel")
plt.title("Violin Plot of IMDb Rating by Genre")
plt.xticks(rotation=45)
plt.show()

# %%
# Pair Plot for IMDb Rating, MetaScore, and Duration
sns.pairplot(data[["IMDb Rating", "MetaScore", "Duration (minutes)"]], diag_kind="kde")
plt.suptitle("Pair Plot for IMDb Rating, MetaScore, and Duration", y=1.02)
plt.show()

# %%
# Scatter Plot of MetaScore vs IMDb Rating with Linear Regression Fit
plt.figure(figsize=(10, 8))
sns.regplot(x="MetaScore", y="IMDb Rating", data=data, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.title("Scatter Plot of MetaScore vs IMDb Rating with Linear Regression Fit")
plt.show()

# %%
# Bar Plot of Top 5 Longest Movies
top_5_longest = data.nlargest(5, "Duration (minutes)")[["Title", "Duration (minutes)"]]
plt.figure(figsize=(10, 8))
sns.barplot(x=top_5_longest["Title"], y=top_5_longest["Duration (minutes)"], color="blue")
plt.title("Top 5 Longest Movies by Duration")
plt.ylabel("Duration (minutes)")
plt.xlabel("Movie Title")
plt.xticks(rotation=45)
plt.show()

# %%
# Count the occurrences of each genre
genre_counts = data['Genre'].value_counts()

# Plot a pie chart
plt.figure(figsize=(10, 10))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Set2"), explode=[0.05]*len(genre_counts))
plt.title('Distribution of Movies by Genre')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is drawn as a circle.
plt.show()

# %%
# Count the occurrences of each Certificates
Certificates_counts = data['Certificates'].value_counts()

# Plot a pie chart
plt.figure(figsize=(15, 15))
plt.pie(Certificates_counts, labels=Certificates_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Set2"), explode=[0.05]*len(genre_counts))
plt.title('Distribution of Movies by Genre')
plt.axis('equal')# Equal aspect ratio ensures that pie chart is drawn as a circle.
plt.show()
